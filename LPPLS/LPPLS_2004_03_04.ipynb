# %% [markdown]
# # 股市泡沫檢測器 - FinLab
# 這是一個泡沫檢測器，只要輸入[yahoo finance](https://finance.yahoo.com/)上找到的股票代號，即可查看該股票是否有泡沫，或是反泡沫。此程式碼使用 [lppls package](https://github.com/Boulder-Investment-Technologies/lppls) 讓我們非常方便的來使用 LPPL 這個數學工具。

# %%
#@title 下載歷史價格

try:
    import yfinance as yf
except:
    # !pip install lppls > log.txt
    # !pip install yfinance > log.txt

asset_symbol = "^TWII" #@param {type:"string"}

import yfinance as yf
stock = yf.Ticker(asset_symbol)

# get historical market data
data = stock.history(period="max")
data.Close.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
pip install -U lppls > log.txt

# %%
#@title LPPL 分析
variable_name = "2004-03-04" #@param {type:"date"}
ndates = 210 # @param {"type":"slider","min":0,"max":1080,"step":1}

from lppls import lppls, data_loader
import numpy as np
import pandas as pd
from datetime import datetime as dt
# %matplotlib inline

# read example dataset into df
#data = data_loader.nasdaq_dotcom()

# convert time to ordinal

processing_data = data.loc[:variable_name].iloc[-ndates:].reset_index()
processing_data.Date = pd.to_datetime(processing_data['Date']).dt.date.astype(str)

time = [pd.Timestamp.toordinal(dt.strptime(t1, '%Y-%m-%d')) for t1 in processing_data['Date']]

# create list of observation data
price = np.log(processing_data['Close'].values)

# create observations array (expected format for LPPLS observations)
observations = np.array([time, price])

# set the max number for searches to perform before giving-up
# the literature suggests 25
MAX_SEARCHES = 25

# instantiate a new LPPLS model with the Nasdaq Dot-com bubble dataset
lppls_model = lppls.LPPLS(observations=observations)

# fit the model to the data and get back the params
tc, m, w, a, b, c, c1, c2, O, D = lppls_model.fit(MAX_SEARCHES)

# visualize the fit
lppls_model.plot_fit()
# Calculate and print the crash date
crash_date = dt.fromordinal(int(tc)).strftime('%Y-%m-%d')
print(f"Crash Date (tc): {crash_date}")


import datetime
print('( b < 0   ) ', b)
print('(|c| < 1  ) ', c)
print('(0 < m < 1) ', m)
# Out:
# Crash Date (tc): 3132-04-28
# ( b < 0   )  -262.0428264575615
# (|c| < 1  )  262.0811075266784
# (0 < m < 1)  0.41217966136485207

# %% [markdown]
# # 小週期來觀看這次的行情

# %%
# compute the confidence indicator
res = lppls_model.mp_compute_nested_fits(
    workers=8,
    window_size=20,
    smallest_window_size=5,
    outer_increment=1,
    inner_increment=1,
    max_searches=500,
    # filter_conditions_config={} # not implemented in 0.6.x
)

lppls_model.plot_confidence_indicators(res)
# should give a plot like the following...
# Out:
#   0%|          | 0/191 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#   4%|▍         | 8/191 [00:24<04:06,  1.34s/it]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#  34%|███▍      | 65/191 [00:49<00:50,  2.48it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#  42%|████▏     | 81/191 [00:56<00:47,  2.32it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#  43%|████▎     | 83/191 [00:57<00:50,  2.16it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in scalar divide
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#  60%|█████▉    | 114/191 [01:06<00:20,  3.84it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#  62%|██████▏   | 119/191 [01:10<00:34,  2.11it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in scalar divide
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#  93%|█████████▎| 178/191 [01:33<00:03,  3.62it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in scalar divide
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# 100%|██████████| 191/191 [01:38<00:00,  1.95it/s]

# %%
# compute the confidence indicator
res = lppls_model.mp_compute_nested_fits(
    workers=8,
    window_size=15,
    smallest_window_size=5,
    outer_increment=1,
    inner_increment=1,
    max_searches=500,
    # filter_conditions_config={} # not implemented in 0.6.x
)

lppls_model.plot_confidence_indicators(res)
# should give a plot like the following...
# Out:
#   0%|          | 0/196 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#   1%|          | 1/196 [00:21<1:10:02, 21.55s/it]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#   1%|          | 2/196 [00:22<30:20,  9.39s/it]  /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#   2%|▏         | 3/196 [00:24<18:53,  5.87s/it]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#   7%|▋         | 14/196 [00:28<01:46,  1.71it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#  47%|████▋     | 93/196 [00:52<00:27,  3.74it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in scalar divide
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#  52%|█████▏    | 101/196 [00:54<00:22,  4.21it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#  76%|███████▌  | 148/196 [01:11<00:14,  3.23it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#  98%|█████████▊| 193/196 [01:27<00:00,  3.87it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in scalar divide
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# 100%|██████████| 196/196 [01:27<00:00,  2.23it/s]

# %%
# compute the confidence indicator
res = lppls_model.mp_compute_nested_fits(
    workers=8,
    window_size=15,
    smallest_window_size=3,
    outer_increment=1,
    inner_increment=1,
    max_searches=500,
    # filter_conditions_config={} # not implemented in 0.6.x
)

lppls_model.plot_confidence_indicators(res)
# should give a plot like the following...
# Out:
#   0%|          | 0/196 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#   1%|          | 1/196 [00:25<1:22:33, 25.40s/it]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#  14%|█▍        | 28/196 [00:35<01:23,  2.02it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#  21%|██▏       | 42/196 [00:38<00:33,  4.55it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#  30%|███       | 59/196 [00:48<01:17,  1.76it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#  83%|████████▎ | 163/196 [01:23<00:13,  2.49it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#  91%|█████████ | 178/196 [01:29<00:06,  2.96it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in scalar divide
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# 100%|██████████| 196/196 [01:34<00:00,  2.07it/s]

# %%
# compute the confidence indicator
res = lppls_model.mp_compute_nested_fits(
    workers=8,
    window_size=15,
    smallest_window_size=3,
    outer_increment=1,
    inner_increment=1,
    max_searches=500,
    # filter_conditions_config={} # not implemented in 0.6.x
)

lppls_model.plot_confidence_indicators(res)
# should give a plot like the following...
# Out:
#   0%|          | 0/196 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#   2%|▏         | 4/196 [00:28<15:47,  4.93s/it]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#  22%|██▏       | 43/196 [00:43<00:49,  3.09it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#  26%|██▌       | 51/196 [00:46<00:53,  2.74it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#  63%|██████▎   | 123/196 [01:10<00:17,  4.16it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in scalar divide
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#  77%|███████▋  | 151/196 [01:22<00:17,  2.64it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# 100%|██████████| 196/196 [01:39<00:00,  1.96it/s]

# %%
# compute the confidence indicator
res = lppls_model.mp_compute_nested_fits(
    workers=8,
    window_size=10,
    smallest_window_size=3,
    outer_increment=1,
    inner_increment=1,
    max_searches=500,
    # filter_conditions_config={} # not implemented in 0.6.x
)

lppls_model.plot_confidence_indicators(res)
# should give a plot like the following...
# Out:
#   0%|          | 0/201 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#   0%|          | 1/201 [00:20<1:07:26, 20.23s/it]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#   1%|          | 2/201 [00:20<28:46,  8.68s/it]  /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#   3%|▎         | 6/201 [00:22<05:16,  1.62s/it]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#   8%|▊         | 17/201 [00:23<00:55,  3.32it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#  14%|█▍        | 28/201 [00:27<00:53,  3.25it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in scalar divide
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#  44%|████▍     | 89/201 [00:42<00:20,  5.54it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#  83%|████████▎ | 167/201 [01:01<00:06,  4.87it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in scalar divide
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# 100%|██████████| 201/201 [01:10<00:00,  2.85it/s]

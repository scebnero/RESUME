# %% [markdown]
# # 股市泡沫檢測器 - FinLab
# 這是一個泡沫檢測器，只要輸入[yahoo finance](https://finance.yahoo.com/)上找到的股票代號，即可查看該股票是否有泡沫，或是反泡沫。此程式碼使用 [lppls package](https://github.com/Boulder-Investment-Technologies/lppls) 讓我們非常方便的來使用 LPPL 這個數學工具。

# %%
#@title 下載歷史價格

try:
    import yfinance as yf
except:
    # !pip install lppls > log.txt
    # !pip install yfinance > log.txt

asset_symbol = "0050.TW" #@param {type:"string"}

import yfinance as yf
stock = yf.Ticker(asset_symbol)

# get historical market data
data = stock.history(period="max")
data.Close.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
pip install -U lppls > log.txt

# %%
#@title LPPL 分析
variable_name = "2011-06-07" #@param {type:"date"}
ndates = 570 # @param {"type":"slider","min":0,"max":1080,"step":1}

from lppls import lppls, data_loader
import numpy as np
import pandas as pd
from datetime import datetime as dt
# %matplotlib inline

# read example dataset into df
#data = data_loader.nasdaq_dotcom()

# convert time to ordinal

processing_data = data.loc[:variable_name].iloc[-ndates:].reset_index()
processing_data.Date = pd.to_datetime(processing_data['Date']).dt.date.astype(str)

time = [pd.Timestamp.toordinal(dt.strptime(t1, '%Y-%m-%d')) for t1 in processing_data['Date']]

# create list of observation data
price = np.log(processing_data['Close'].values)

# create observations array (expected format for LPPLS observations)
observations = np.array([time, price])

# set the max number for searches to perform before giving-up
# the literature suggests 25
MAX_SEARCHES = 25

# instantiate a new LPPLS model with the Nasdaq Dot-com bubble dataset
lppls_model = lppls.LPPLS(observations=observations)

# fit the model to the data and get back the params
tc, m, w, a, b, c, c1, c2, O, D = lppls_model.fit(MAX_SEARCHES)

# visualize the fit
lppls_model.plot_fit()
# Calculate and print the crash date
crash_date = dt.fromordinal(int(tc)).strftime('%Y-%m-%d')
print(f"Crash Date (tc): {crash_date}")


import datetime
print('( b < 0   ) ', b)
print('(|c| < 1  ) ', c)
print('(0 < m < 1) ', m)
# Out:
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:213: RuntimeWarning: invalid value encountered in log
#   O = (w / (2.0 * np.pi)) * np.log((tc - first) / (tc - last))
# Crash Date (tc): 2009-02-27
# ( b < 0   )  0.004475272316151699
# (|c| < 1  )  0.003513296533419336
# (0 < m < 1)  0.9862271277083052

# %% [markdown]
# # 小週期來觀看這次的行情

# %%
# compute the confidence indicator
res = lppls_model.mp_compute_nested_fits(
    workers=8,
    window_size=20,
    smallest_window_size=5,
    outer_increment=1,
    inner_increment=1,
    max_searches=500,
    # filter_conditions_config={} # not implemented in 0.6.x
)

lppls_model.plot_confidence_indicators(res)
# should give a plot like the following...
# Out:
#   0%|          | 0/551 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#   7%|▋         | 38/551 [00:50<04:43,  1.81it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#  21%|██        | 115/551 [01:29<02:58,  2.44it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#  26%|██▌       | 143/551 [01:43<02:52,  2.36it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#  29%|██▉       | 161/551 [01:50<02:11,  2.97it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#  31%|███       | 169/551 [01:53<01:56,  3.28it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in scalar divide
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#  36%|███▋      | 200/551 [02:08<02:21,  2.48it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in scalar divide
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#  47%|████▋     | 261/551 [02:30<01:07,  4.30it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in scalar divide
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#  48%|████▊     | 262/551 [02:31<01:46,  2.73it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in scalar divide
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#  62%|██████▏   | 339/551 [03:04<00:50,  4.20it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#  74%|███████▎  | 405/551 [03:32<01:04,  2.25it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#  89%|████████▊ | 488/551 [04:06<00:31,  2.00it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# 100%|██████████| 551/551 [04:33<00:00,  2.02it/s]

# %%
# compute the confidence indicator
res = lppls_model.mp_compute_nested_fits(
    workers=8,
    window_size=15,
    smallest_window_size=5,
    outer_increment=1,
    inner_increment=1,
    max_searches=500,
    # filter_conditions_config={} # not implemented in 0.6.x
)

lppls_model.plot_confidence_indicators(res)
# should give a plot like the following...
# Out:
#   0%|          | 0/556 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#   0%|          | 1/556 [00:19<2:56:30, 19.08s/it]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#   0%|          | 2/556 [00:21<1:23:50,  9.08s/it]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#   1%|          | 4/556 [00:23<35:48,  3.89s/it]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#   1%|          | 5/556 [00:28<36:26,  3.97s/it]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#   3%|▎         | 18/556 [00:33<05:18,  1.69it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#  11%|█         | 61/556 [00:53<03:45,  2.19it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in scalar divide
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#  22%|██▏       | 124/556 [01:26<05:31,  1.30it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in scalar divide
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#  28%|██▊       | 157/556 [01:43<04:50,  1.37it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#  32%|███▏      | 180/556 [01:53<02:18,  2.71it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in scalar divide
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#  50%|█████     | 278/556 [02:46<01:51,  2.50it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#  69%|██████▉   | 383/556 [03:41<01:14,  2.31it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# 100%|██████████| 556/556 [05:10<00:00,  1.79it/s]

# %%
# compute the confidence indicator
res = lppls_model.mp_compute_nested_fits(
    workers=8,
    window_size=15,
    smallest_window_size=3,
    outer_increment=1,
    inner_increment=1,
    max_searches=500,
    # filter_conditions_config={} # not implemented in 0.6.x
)

lppls_model.plot_confidence_indicators(res)
# should give a plot like the following...
# Out:
#   0%|          | 0/556 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#   1%|          | 4/556 [00:28<51:10,  5.56s/it]  /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#   1%|          | 6/556 [00:30<32:57,  3.60s/it]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in scalar divide
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#   1%|▏         | 7/556 [00:31<26:35,  2.91s/it]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#   5%|▌         | 30/556 [00:37<03:03,  2.86it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in scalar divide
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#   8%|▊         | 44/556 [00:47<05:18,  1.61it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#  27%|██▋       | 152/556 [01:35<02:59,  2.25it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#  31%|███       | 170/556 [01:44<02:05,  3.08it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#  47%|████▋     | 264/556 [02:27<01:37,  3.00it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in scalar divide
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#  78%|███████▊  | 431/556 [03:48<00:58,  2.15it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#  80%|████████  | 447/556 [03:54<00:43,  2.51it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#  81%|████████  | 450/556 [03:55<00:39,  2.67it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#  89%|████████▉ | 496/556 [04:17<00:28,  2.09it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in scalar divide
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#  96%|█████████▌| 531/556 [04:33<00:08,  3.12it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in scalar divide
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# 100%|██████████| 556/556 [04:47<00:00,  1.94it/s]

# %%
# compute the confidence indicator
res = lppls_model.mp_compute_nested_fits(
    workers=8,
    window_size=15,
    smallest_window_size=3,
    outer_increment=1,
    inner_increment=1,
    max_searches=500,
    # filter_conditions_config={} # not implemented in 0.6.x
)

lppls_model.plot_confidence_indicators(res)
# should give a plot like the following...
# Out:
#   0%|          | 0/556 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#   0%|          | 1/556 [00:18<2:51:50, 18.58s/it]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#   0%|          | 2/556 [00:24<1:42:20, 11.08s/it]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#   1%|          | 4/556 [00:26<44:39,  4.85s/it]  /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#   1%|          | 5/556 [00:29<39:32,  4.31s/it]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#   1%|▏         | 7/556 [00:31<23:58,  2.62s/it]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#   9%|▉         | 52/556 [00:49<03:29,  2.40it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in scalar divide
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#  16%|█▌        | 88/556 [01:11<05:15,  1.48it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#  49%|████▉     | 272/556 [02:46<02:22,  2.00it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in scalar divide
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#  50%|████▉     | 277/556 [02:49<03:03,  1.52it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#  62%|██████▏   | 346/556 [03:29<02:30,  1.40it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in scalar divide
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#  67%|██████▋   | 370/556 [03:38<01:06,  2.80it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#  75%|███████▌  | 419/556 [04:05<01:23,  1.63it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in scalar divide
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#  89%|████████▉ | 495/556 [04:45<00:25,  2.38it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in scalar divide
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in scalar divide
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# 100%|██████████| 556/556 [05:16<00:00,  1.76it/s]

# %%
# compute the confidence indicator
res = lppls_model.mp_compute_nested_fits(
    workers=8,
    window_size=10,
    smallest_window_size=3,
    outer_increment=1,
    inner_increment=1,
    max_searches=500,
    # filter_conditions_config={} # not implemented in 0.6.x
)

lppls_model.plot_confidence_indicators(res)
# should give a plot like the following...
# Out:
#   0%|          | 0/561 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#   1%|          | 3/561 [00:22<55:10,  5.93s/it]  /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#   1%|          | 5/561 [00:23<29:04,  3.14s/it]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#   1%|          | 6/561 [00:24<23:02,  2.49s/it]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#   1%|          | 7/561 [00:24<18:09,  1.97s/it]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#   6%|▋         | 36/561 [00:35<02:53,  3.02it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#  23%|██▎       | 130/561 [01:13<02:04,  3.47it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#  28%|██▊       | 156/561 [01:22<02:50,  2.37it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#  40%|███▉      | 224/561 [01:47<01:31,  3.67it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in scalar divide
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#  62%|██████▏   | 350/561 [02:33<02:03,  1.71it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in scalar divide
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#  65%|██████▌   | 366/561 [02:40<00:59,  3.28it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in scalar divide
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# 100%|██████████| 561/561 [03:54<00:00,  2.40it/s]

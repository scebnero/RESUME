# %% [markdown]
# # 股市泡沫檢測器 - FinLab
# 這是一個泡沫檢測器，只要輸入[yahoo finance](https://finance.yahoo.com/)上找到的股票代號，即可查看該股票是否有泡沫，或是反泡沫。此程式碼使用 [lppls package](https://github.com/Boulder-Investment-Technologies/lppls) 讓我們非常方便的來使用 LPPL 這個數學工具。

# %%
#@title 下載歷史價格

try:
    import yfinance as yf
except:
    # !pip install lppls > log.txt
    # !pip install yfinance > log.txt

asset_symbol = "0050.TW" #@param {type:"string"}

import yfinance as yf
stock = yf.Ticker(asset_symbol)

# get historical market data
data = stock.history(period="max")
data.Close.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
pip install -U lppls > log.txt

# %%
#@title LPPL 分析
variable_name = "2022-01-05" #@param {type:"date"}
ndates = 430 # @param {"type":"slider","min":0,"max":1080,"step":1}

from lppls import lppls, data_loader
import numpy as np
import pandas as pd
from datetime import datetime as dt
# %matplotlib inline

# read example dataset into df
#data = data_loader.nasdaq_dotcom()

# convert time to ordinal

processing_data = data.loc[:variable_name].iloc[-ndates:].reset_index()
processing_data.Date = pd.to_datetime(processing_data['Date']).dt.date.astype(str)

time = [pd.Timestamp.toordinal(dt.strptime(t1, '%Y-%m-%d')) for t1 in processing_data['Date']]

# create list of observation data
price = np.log(processing_data['Close'].values)

# create observations array (expected format for LPPLS observations)
observations = np.array([time, price])

# set the max number for searches to perform before giving-up
# the literature suggests 25
MAX_SEARCHES = 25

# instantiate a new LPPLS model with the Nasdaq Dot-com bubble dataset
lppls_model = lppls.LPPLS(observations=observations)

# fit the model to the data and get back the params
tc, m, w, a, b, c, c1, c2, O, D = lppls_model.fit(MAX_SEARCHES)

# visualize the fit
lppls_model.plot_fit()
# Calculate and print the crash date
crash_date = dt.fromordinal(int(tc)).strftime('%Y-%m-%d')
print(f"Crash Date (tc): {crash_date}")


import datetime
print('( b < 0   ) ', b)
print('(|c| < 1  ) ', c)
print('(0 < m < 1) ', m)
# Out:
# Crash Date (tc): 2022-03-28
# ( b < 0   )  -0.0001031796096385456
# (|c| < 1  )  -4.7344502016038324e-05
# (0 < m < 1)  1.2747058524905757

# %% [markdown]
# # 小週期來觀看這次的行情
# 從signal value=15 -> signal value = **38**
# 從藍燈 到 紅燈
# # 從小周期來分析(涵蓋窗口最大為20%最小為4%)

# %%
# compute the confidence indicator
res = lppls_model.mp_compute_nested_fits(
    workers=8,
    window_size=15,
    smallest_window_size=3,
    outer_increment=1,
    inner_increment=1,
    max_searches=500,
    # filter_conditions_config={} # not implemented in 0.6.x
)

lppls_model.plot_confidence_indicators(res)
# should give a plot like the following...
# Out:
#   0%|          | 0/416 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#   0%|          | 1/416 [00:25<2:55:07, 25.32s/it]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#   1%|          | 3/416 [00:26<49:22,  7.17s/it]  /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#   1%|          | 4/416 [00:29<38:15,  5.57s/it]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#   1%|▏         | 6/416 [00:30<20:12,  2.96s/it]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#   2%|▏         | 8/416 [00:31<13:43,  2.02s/it]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#  12%|█▏        | 48/416 [00:45<03:44,  1.64it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#  15%|█▌        | 63/416 [00:51<02:18,  2.54it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#  29%|██▉       | 120/416 [01:14<01:31,  3.23it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#  67%|██████▋   | 279/416 [02:24<00:49,  2.75it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#  69%|██████▉   | 288/416 [02:27<00:36,  3.47it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in scalar divide
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#  96%|█████████▌| 400/416 [03:16<00:04,  3.25it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#  99%|█████████▉| 411/416 [03:21<00:02,  2.26it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in scalar divide
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# 100%|██████████| 416/416 [03:21<00:00,  2.06it/s]

# %%
# compute the confidence indicator
res = lppls_model.mp_compute_nested_fits(
    workers=8,
    window_size=15,
    smallest_window_size=5,
    outer_increment=1,
    inner_increment=1,
    max_searches=500,
    # filter_conditions_config={} # not implemented in 0.6.x
)

lppls_model.plot_confidence_indicators(res)
# should give a plot like the following...
# Out:
#   0%|          | 0/416 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#   0%|          | 1/416 [00:20<2:20:05, 20.25s/it]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#   0%|          | 2/416 [00:21<1:02:33,  9.07s/it]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#   1%|          | 3/416 [00:23<39:09,  5.69s/it]  /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#  11%|█▏        | 47/416 [00:38<02:16,  2.70it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#  13%|█▎        | 53/416 [00:40<01:44,  3.48it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in scalar divide
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#  50%|█████     | 209/416 [01:37<00:47,  4.33it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in scalar divide
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#  62%|██████▏   | 258/416 [01:55<00:39,  4.05it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#  68%|██████▊   | 282/416 [02:03<00:41,  3.22it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#  82%|████████▏ | 342/416 [02:26<00:37,  1.99it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in scalar divide
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#  85%|████████▌ | 354/416 [02:30<00:19,  3.13it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in scalar divide
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#  88%|████████▊ | 368/416 [02:34<00:11,  4.02it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
#  96%|█████████▌| 399/416 [02:46<00:06,  2.57it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: divide by zero encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# 100%|██████████| 416/416 [02:51<00:00,  2.43it/s]

# %% [markdown]
# # 大週期來觀看這次的行情
# # 從signal value=15 -> signal value = **38**
# # 從藍燈 到 紅燈
# 從大周期來分析(涵蓋窗口最大為75%)
# 可能會忽略小波動的問題

# %%
# compute the confidence indicator
res = lppls_model.mp_compute_nested_fits(
    workers=8,
    window_size=400,
    smallest_window_size=100,
    outer_increment=1,
    inner_increment=5,
    max_searches=50,
    # filter_conditions_config={} # not implemented in 0.6.x
)

lppls_model.plot_confidence_indicators(res)
# should give a plot like the following...
# Out:
#   0%|          | 0/101 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# /usr/local/lib/python3.10/dist-packages/lppls/lppls.py:617: RuntimeWarning: invalid value encountered in log
#   return (w / (2.0 * np.pi)) * np.log((tc - t1) / (tc - t2))
# 100%|██████████| 101/101 [06:24<00:00,  3.81s/it]
